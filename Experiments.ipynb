# %%
# %load_ext autoreload

# %%
# %run -i 'main.py' --gpu_use=1 --which_gpu=0
# Out:
# Namespace(gpu_use=1, which_gpu=0)
# ['reggae', 'classical', 'country', 'jazz', 'metal', 'pop', 'disco', 'hiphop', 'rock', 'blues']
# (443, 128, 1287)
# (443, 128, 1287) (443,) (197, 128, 1287) (197,) (290, 128, 1287) (290,)
# model_1DCNN(
#   (conv0): Sequential(
#     (0): Conv1d(128, 32, kernel_size=(8,), stride=(1,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv1): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(8,), stride=(1,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv1d(32, 64, kernel_size=(4,), stride=(1,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
# ...

# %%
# %run -i 'main.py' --gpu_use=1 --which_gpu=0
# Out:
# Namespace(gpu_use=1, which_gpu=0)
# ['reggae', 'classical', 'country', 'jazz', 'metal', 'pop', 'disco', 'hiphop', 'rock', 'blues']
# (4430, 128, 128)
# (4430, 128, 128) (4430,) (1970, 128, 128) (1970,) (2900, 128, 128) (2900,)
# model_1DCNN_short(
#   (conv0): Sequential(
#     (0): Conv1d(128, 32, kernel_size=(9,), stride=(1,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv1): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(8,), stride=(1,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv1d(32, 64, kernel_size=(4,), stride=(3,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# plain: Test Accuracy: 0.5207
#
# # 3s splits without averaging of result
# Test Accuracy: 0.5590
#
# (443, 128, 1287) (443,) (197, 128, 1287) (197,) (290, 128, 1287) (290,)
# model_1DCNN(
#   (conv0): Sequential(
#     (0): Conv1d(128, 32, kernel_size=(8,), stride=(1,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv1): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(8,), stride=(1,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=8, stride=8, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv1d(32, 64, kernel_size=(4,), stride=(1,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc0): Linear(in_features=256, out_features=64, bias=True)
#   (fc1): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
path = os.path.abspath('../..')
mel_path = path + '/gtzan_mel'
mel = np.load(mel_path +'/blues/blues.00045.npy')
mel
# Out:
# array([[6.6990161e-01, 3.7650773e-01, 4.2052668e-01, ..., 2.4691856e-01,
#         3.1386757e-01, 1.7449795e-01],
#        [9.4072378e-01, 7.1411455e-01, 1.0616822e+00, ..., 3.3857328e-01,
#         4.2921627e-01, 3.6669487e-01],
#        [9.8529458e-01, 7.8986245e-01, 1.3927085e+00, ..., 8.1729567e-01,
#         6.6713756e-01, 6.9279540e-01],
#        ...,
#        [2.5567310e-03, 1.7779057e-04, 1.8117324e-04, ..., 2.5232119e-04,
#         2.0861955e-04, 3.5291596e-04],
#        [2.4695520e-03, 6.5120585e-05, 5.6098950e-05, ..., 6.9935624e-05,
#         5.6794022e-05, 1.2212024e-04],
#        [2.4294013e-03, 3.3567940e-05, 3.7775073e-05, ..., 2.7846680e-05,
#         2.4686078e-05, 2.9587585e-05]], dtype=float32)

# %%
mel.size
# Out:
# 164736

# %%
mel.shape
# Out:
# (128, 1287)

# %%
# %run -i 'feature_extraction.py'
# Out:
# ERROR:root:File `u'feature_extraction.py'` not found.

# %%
for i in range(1):
    print i
# Out:
# 0

# %%
import torch
import torch.nn as nn

in_ten = torch.randn(5, 128, 1287)
m = nn.Conv1d(128, 32, kernel_size=8, stride=1, padding=0)
output = m(in_ten)

# %%
output.shape
# Out:
# torch.Size([5, 32, 1280])

# %%
m1 = nn.BatchNorm1d(32)
output2 = m1(output)
print(output2.shape)
# Out:
# torch.Size([5, 32, 1280])

# %%
m2 = nn.ReLU()
output3 = m2(output2)
print(output3.shape)
m3 = nn.MaxPool1d(8, stride=8)
output4 = m3(output3)
print(output4.shape)
# Out:
# torch.Size([5, 32, 1280])
# torch.Size([5, 32, 160])
