# %%
run -i 'feature_extraction.py'
# Out:
# 930
# 0, 0, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_0.npy
# 0, 1, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_1.npy
# 0, 2, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_2.npy
# 0, 3, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_3.npy
# 0, 4, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_4.npy
# 0, 5, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_5.npy
# 0, 6, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_6.npy
# 0, 7, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_7.npy
# 0, 8, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_8.npy
# 0, 9, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00029_9.npy
# 1, 0, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00030_0.npy
# 1, 1, (128, 1287)/home/jonas/git/gct634-2018/gtzan_mels/blues/blues.00030_1.npy
# ...

# %%
run -i 'train_test.py'
# Out:
# ['reggae', 'classical', 'country', 'jazz', 'metal', 'pop', 'disco', 'hiphop', 'rock', 'blues']
# (443, 128, 1287) (443,)
# Epoch [1/50], Iter [10/88] loss : 2.1516
# Epoch [1/50], Iter [20/88] loss : 2.5544
# Epoch [1/50], Iter [30/88] loss : 2.1410
# train_test.py:226: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   print ("Epoch [%d/%d], Iter [%d/%d] loss : %.4f" % (epoch+1, num_epochs, i+1, len(train_loader), loss.data[0]))
# Epoch [1/50], Iter [40/88] loss : 2.1276
# Epoch [1/50], Iter [50/88] loss : 2.2941
# Epoch [1/50], Iter [60/88] loss : 2.0837
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jonas/git/gct634-2018/hw2/train_test.py in <module>()
#     269 # run
#     270 start_time = time.time()
# ...

# %% [markdown]
# Baseline Code performance with GPU: 0.5379
